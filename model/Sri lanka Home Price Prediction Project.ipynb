# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/ML/ML/Sri_lanka_Home_Price_Prediction_Project/house_prices.csv')
df.head(3)
# Out:
#                                                Title  \
# 0        House with Land for Sale in Matara for sale
# 1  à¶
# à¶½à·à¶­à· à¶à·à¶¸à¶» 3 à¶ à¶à·à· à...
# 2     Kelaniya - House on 20P Land for sale for sale
#
#                                          Sub_title          Price  \
# 0    Posted on 06 Nov 2:32 pm, Matara City, Matara   Rs 5,400,000
# 1  Posted on 24 Oct 7:27 am, Athurugiriya, Colombo  Rs 16,800,000
# 2      Posted on 17 Nov 5:19 pm, Kelaniya, Gampaha  Rs 20,000,000
#
#                              Address Baths     Land_size Beds    House_size  \
# 0  Gangodagama Roard,Hakmana,Matara.     1  50.0 perches    3  1,600.0 sqft
# 1         Athurugiriya Galwarusapare     3   8.0 perches    3  1,480.0 sqft
# 2  Kelaniya- Ranaviru Maldeniya Road     2  20.0 perches    3  2,800.0 sqft
#
#                   Location                                        Description  \
# 0     Matara City,  Matara  Land for sale with house Matara,Hakmana Gangod...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = df.drop(df[['Title','Sub_title','Address','Description','Post_URL','Seller_name','Seller_type','published_date','Geo_Address','Lat','Lon']],axis='columns')
df1.head()
# Out:
#             Price Baths     Land_size Beds    House_size  \
# 0    Rs 5,400,000     1  50.0 perches    3  1,600.0 sqft
# 1   Rs 16,800,000     3   8.0 perches    3  1,480.0 sqft
# 2   Rs 20,000,000     2  20.0 perches    3  2,800.0 sqft
# 3  Rs 187,000,000     5  22.0 perches    5  4,000.0 sqft
# 4    Rs 1,300,000     1   6.3 perches    2    900.0 sqft
#
#                   Location
# 0     Matara City,  Matara
# 1   Athurugiriya,  Colombo
# 2       Kelaniya,  Gampaha
# 3      Colombo 6,  Colombo
# 4       Dehiwala,  Colombo

# %%
df1.isnull().sum()
# Out:
# Price         0
# Baths         0
# Land_size     0
# Beds          0
# House_size    0
# Location      0
# dtype: int64

# %%
#df1.Location.unique()
df1['town'] = df1.Location.apply(lambda x: str(x).split(',')[0])
df1.head()
# Out:
#             Price Baths     Land_size Beds    House_size  \
# 0    Rs 5,400,000     1  50.0 perches    3  1,600.0 sqft
# 1   Rs 16,800,000     3   8.0 perches    3  1,480.0 sqft
# 2   Rs 20,000,000     2  20.0 perches    3  2,800.0 sqft
# 3  Rs 187,000,000     5  22.0 perches    5  4,000.0 sqft
# 4    Rs 1,300,000     1   6.3 perches    2    900.0 sqft
#
#                   Location           town
# 0     Matara City,  Matara    Matara City
# 1   Athurugiriya,  Colombo   Athurugiriya
# 2       Kelaniya,  Gampaha       Kelaniya
# 3      Colombo 6,  Colombo      Colombo 6
# 4       Dehiwala,  Colombo       Dehiwala

# %%
df1 = df1.drop('Location', axis='columns')
df1.head()
# Out:
#             Price Baths     Land_size Beds    House_size           town
# 0    Rs 5,400,000     1  50.0 perches    3  1,600.0 sqft    Matara City
# 1   Rs 16,800,000     3   8.0 perches    3  1,480.0 sqft   Athurugiriya
# 2   Rs 20,000,000     2  20.0 perches    3  2,800.0 sqft       Kelaniya
# 3  Rs 187,000,000     5  22.0 perches    5  4,000.0 sqft      Colombo 6
# 4    Rs 1,300,000     1   6.3 perches    2    900.0 sqft       Dehiwala

# %%
df1['Price'] = df1.Price.str.replace('Rs', '').str.replace(',', '')
df1.head()
# Out:
#         Price Baths     Land_size Beds    House_size           town
# 0     5400000     1  50.0 perches    3  1,600.0 sqft    Matara City
# 1    16800000     3   8.0 perches    3  1,480.0 sqft   Athurugiriya
# 2    20000000     2  20.0 perches    3  2,800.0 sqft       Kelaniya
# 3   187000000     5  22.0 perches    5  4,000.0 sqft      Colombo 6
# 4     1300000     1   6.3 perches    2    900.0 sqft       Dehiwala

# %%
df1['Land_size'] = df1.Land_size.apply(lambda x: str(x).replace(',', '').split()[0])
df1.head()
# Out:
#         Price Baths Land_size Beds    House_size           town
# 0     5400000     1      50.0    3  1,600.0 sqft    Matara City
# 1    16800000     3       8.0    3  1,480.0 sqft   Athurugiriya
# 2    20000000     2      20.0    3  2,800.0 sqft       Kelaniya
# 3   187000000     5      22.0    5  4,000.0 sqft      Colombo 6
# 4     1300000     1       6.3    2    900.0 sqft       Dehiwala

# %%
df1['House_size'] = df1.House_size.apply(lambda x: str(x).replace(',', '')[0])
df1.head()
# Out:
#         Price Baths Land_size Beds House_size           town
# 0     5400000     1      50.0    3          1    Matara City
# 1    16800000     3       8.0    3          1   Athurugiriya
# 2    20000000     2      20.0    3          2       Kelaniya
# 3   187000000     5      22.0    5          4      Colombo 6
# 4     1300000     1       6.3    2          9       Dehiwala

# %%
df1.Beds.unique()
# Out:
# array(['3', '5', '2', '4', '10+', '9', '8', '6', '7', '1', '10'],
#       dtype=object)

# %%
df1.town
df1['town'] = df1['town'].str.strip()

# %%
df1.shape
# Out:
# (15327, 6)

# %%
dummies = pd.get_dummies(df1.town)
dummies
# Out:
#        Ahangama  Akkarepattu  Akuressa  Alawwa  Alutgama  Ambalangoda  \
# 0         False        False     False   False     False        False
# 1         False        False     False   False     False        False
# 2         False        False     False   False     False        False
# 3         False        False     False   False     False        False
# 4         False        False     False   False     False        False
# ...         ...          ...       ...     ...       ...          ...
# 15322     False        False     False   False     False        False
# 15323     False        False     False   False     False        False
# 15324     False        False     False   False     False        False
# 15325     False        False     False   False     False        False
# 15326     False        False     False   False     False        False
#
#        Ambalantota  Ampara City  Ampitiya  Angoda  ...  Warakapola  \
# ...

# %%
df2 = pd.concat([df1,dummies],axis='columns')
df2.columns
# Out:
# Index(['Price', 'Baths', 'Land_size', 'Beds', 'House_size', 'town', 'Ahangama',
#        'Akkarepattu', 'Akuressa', 'Alawwa',
#        ...
#        'Warakapola', 'Wariyapola', 'Wattala', 'Wattegama', 'Weligama',
#        'Welimada', 'Wellampitiya', 'Wellawaya', 'Wennappuwa', 'Yatiyantota'],
#       dtype='object', length=178)

# %%
df3 = df2.drop('town', axis='columns')
df3.head()
df3 = df3[df3['Baths'] != '10+']
df3['Baths'] = df3.Baths.astype(float)
df3.Baths.unique()
# Out:
# array([ 1.,  3.,  2.,  5.,  4.,  7.,  6.,  8., 10.,  9.])

# %%
df3 = df3[df3['Beds'] != '10+']
df3['Beds'] = df3.Beds.astype(float)
df3.Beds.unique()
# Out:
# <ipython-input-19-2a2811278823>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Beds'] = df3.Beds.astype(float)
# array([ 3.,  5.,  2.,  4.,  9.,  8.,  6.,  7.,  1., 10.])

# %%
X = df3.drop('Price', axis='columns')
X[:10]
# Out:
#    Baths Land_size  Beds House_size  Ahangama  Akkarepattu  Akuressa  Alawwa  \
# 0    1.0      50.0   3.0          1     False        False     False   False
# 1    3.0       8.0   3.0          1     False        False     False   False
# 2    2.0      20.0   3.0          2     False        False     False   False
# 3    5.0      22.0   5.0          4     False        False     False   False
# 4    1.0       6.3   2.0          9     False        False     False   False
# 5    4.0      11.0   4.0          3     False        False     False   False
# 6    4.0      10.0   4.0          4     False        False     False   False
# 7    3.0       9.0   3.0          1     False        False     False   False
# 8    4.0      10.0   4.0          4     False        False     False   False
# 9    1.0    3000.0   3.0          2     False        False     False   False
#
#    Alutgama  Ambalangoda  ...  Warakapola  Wariyapola  Wattala  Wattegama  \
# ...

# %%
y = df3.Price

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
def get_score(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    return model.score(X_test, y_test)

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()
bg = BaggingRegressor()
rf = RandomForestRegressor()
svr = SVR()
get_score(lr, X_train, X_test, y_train, y_test)
# Out:
# -1.7568922189210272e+16

# %%
get_score(dt, X_train, X_test, y_train, y_test)
# Out:
# 0.42164529371371007

# %%
get_score(dt, X_train, X_test, y_train, y_test)
# Out:
# 0.43919589735962683

# %%
get_score(bg, X_train, X_test, y_train, y_test)
# Out:
# 0.4902229998127531

# %%
get_score(rf, X_train, X_test, y_train, y_test)
# Out:
# 0.45926063876340406

# %%
get_score(svr, X_train, X_test, y_train, y_test)
# Out:
# -0.04932737099862328

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
scores = cross_val_score(LinearRegression(), X, y, cv=5)
np.average(scores)
# Out:
# -3.07337407248667e+17

# %%
scores = cross_val_score(DecisionTreeRegressor(), X, y, cv=5)
np.average(scores)
# Out:
# 0.5018830795067888

# %%
scores = cross_val_score(BaggingRegressor(), X, y, cv=5)
np.average(scores)
# Out:
# 0.5300363926119527

# %%
rf_model = RandomForestRegressor()
scores = cross_val_score(rf_model, X, y, cv=5)
np.average(scores)
# Out:
# 0.5564884371755532

# %%
scores = cross_val_score(SVR(), X, y, cv=10)
np.average(scores)
# Out:
# -0.04639259215502243

# %%
params = {
             'max_depth': [None, 5, 10],
            'min_samples_split': [2, 5, 10],
             'max_samples': [0.5, 0.8, 1.0],
            'max_features': [0.5, 0.8, 1.0],
            'bootstrap': [True, False],
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
ml_models = {
    'DecisionTreeRegressor': {
        'model': DecisionTreeRegressor(),
        'params': {
            'criterion': ['squared_error', 'friedman_mse'],
            'splitter': ['best', 'random'],
            'max_depth': [None, 5, 10, 15],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 4],
            'max_features': [None, 'sqrt', 'log2'],
            'max_leaf_nodes': [None, 5, 10, 20],
            'random_state': [None, 42]
        }
    },
    'BaggingRegressor': {
        'model': BaggingRegressor(),
        'params': {
            'n_estimators': [10, 50, 100],
            'max_samples': [0.5, 0.8, 1.0],
            'max_features': [0.5, 0.8, 1.0],
            'bootstrap': [True, False],
            'bootstrap_features': [True, False],
            'random_state': [None, 42],
            'n_jobs': [None, -1]
        }
    },
    'RandomForestRegressor': {
        'model': RandomForestRegressor(),
        'params': {
            'n_estimators': [100, 200, 300],
            'criterion': ['mse', 'mae'],
            'max_depth': [None, 5, 10],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 4],
            'max_features': ['auto', 'sqrt', 'log2'],
            'max_leaf_nodes': [None, 5, 10],
            'random_state': [None, 42],
            'n_jobs': [None, -1]
        }
    }
}

# %%
scores = []
for model_name, item in ml_models.items():
    gs_clf = GridSearchCV(item['model'], item['params'], cv=5, return_train_score=False)
    gs_clf.fit(X, y)
    scores.append({
        'model': model_name,
        'best_score': gs_clf.best_score_,
        'best_params': gs_clf.best_params_
    })
df12 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df12

# %%
bg_clf = GridSearchCV(BaggingRegressor(), params, cv=5, return_train_score=False)
bg_clf.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[143], line 2
#       1 bg_clf = GridSearchCV(BaggingRegressor(), params, cv=5, return_train_score=False)
# ----> 2 bg_clf.fit(X, y)
#
# File //anaconda3/envs/envml/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File //anaconda3/envs/envml/lib/python3.11/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
# ...

# %%
bg_clf.best_score_

# %%
params = {
            'n_estimators': [100, 200, 300],
            'criterion': ['mse', 'mae'],
            'max_depth': [None, 5, 10],
            'min_samples_split': [2, 5, 10],
            'max_features': ['auto', 'sqrt', 'log2'],
}

# %%
rf_clf = GridSearchCV(RandomForestRegressor(), params, cv=5, return_train_score=False)
rf_clf.fit(X, y)

# %%
rf_clf.best_score_

# %%
rf_model = RandomForestRegressor()
scores = cross_val_score(rf_model, X, y, cv=5)
np.average(scores)
# Out:
# 0.5531193285311691

# %%
rf_model.fit(X, y)
# Out:
# RandomForestRegressor()

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
def predict_price(Baths, Land_size, Beds, House_size, location):
    try:
        loc_index = np.where(X.columns == location)[0][0]
    except IndexError:
        # Handle case where location is not found
        print(f"Location '{location}' not found in X.columns")
        return None

    res = np.zeros(len(X.columns))
    res[0] = Baths
    res[1] = Land_size
    res[2] = Beds
    res[3] = House_size

    if loc_index >= 0:
        res[loc_index] = 1

    return rf_model.predict([res])[0]

# %%
predict_price(1,50,3,1,'Matara City')
# Out:
# //anaconda3/envs/envml/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 7499141.666666665

# %%
import pickle
with open('srilanka_home_prices_model.pickle', 'wb') as f:
    pickle.dump(rf_model, f)

# %%
import json
columns = {
    'data_columns' = [col.lower() for col in X.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))

import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
# Out:
#   Cell In[285], line 3
#     'data_columns' = [col.lower() for col in X.columns]
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
